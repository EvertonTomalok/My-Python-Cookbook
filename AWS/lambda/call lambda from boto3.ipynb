# %%
import boto3

client = boto3.client(
    'lambda',
    aws_access_key_id="AKIA3FHSM7KX53WPRTQD",
    aws_secret_access_key="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",
    region_name = 'sa-east-1',
)

# %%
import json

payload = {
    'a': 1,
    'b': 2,
    'c': 17,
}


event = client.invoke(
    FunctionName='arn:aws:lambda:sa-east-1:767160023727:function:calculate_numbers:1',
    InvocationType='RequestResponse',
    LogType='None',
    Payload=json.dumps(payload)
)

# %%
p = event["Payload"].read()

# %%
p.decode("utf-8")
# Out:
# '20'

# %%
e = client.invoke(
    FunctionName='arn:aws:lambda:sa-east-1:767160023727:function:calculate_numbers:1',
    InvocationType='Event',
    Qualifier='1',
    Payload=json.dumps(payload)
)

# %%
e["Payload"].read()
# Out:
# b''

# %%
response = client.invoke_async(
    FunctionName='arn:aws:lambda:sa-east-1:767160023727:function:calculate_numbers:1',
    InvokeArgs=json.dumps(payload),
)

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': '5e13aacb-4d9b-44ad-a527-7bdbbf5b4fc6',
#   'HTTPStatusCode': 202,
#   'HTTPHeaders': {'date': 'Fri, 07 Aug 2020 21:46:37 GMT',
#    'content-type': 'application/json',
#    'content-length': '0',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '5e13aacb-4d9b-44ad-a527-7bdbbf5b4fc6'},
#   'RetryAttempts': 0},
#  'Status': 202}

# %%
import threading
import time
import logging
from random import randint

logging.basicConfig(level=logging.DEBUG,
                    format='(%(threadName)-10s) %(message)s',
                    )

def daemon(i, payload):
    logging.debug(f"Starting {i}")
    event = client.invoke(
        FunctionName='arn:aws:lambda:sa-east-1:767160023727:function:calculate_numbers:1',
        InvocationType='RequestResponse',
        LogType='None',
        Payload=json.dumps(payload)
    )
    print(f"Finishing {i} " + event["Payload"].read().decode("utf-8"))

for i in range(25):
    payload = payload = {
        'a': randint(1,25),
        'b': randint(1,25),
        'c': randint(1,25),
    }
    d = threading.Thread(name='daemon', target=daemon, args=[i, payload])
    d.start()
# Out:
# (daemon    ) Starting 0
# (daemon    ) Starting 1
# (daemon    ) Starting 2
# (daemon    ) Starting 3
# (daemon    ) Event before-parameter-build.lambda.Invoke: calling handler <function generate_idempotent_uuid at 0x7f9ac0358af0>
# (daemon    ) Starting 4
# (daemon    ) Starting 5
# (daemon    ) Event before-parameter-build.lambda.Invoke: calling handler <function generate_idempotent_uuid at 0x7f9ac0358af0>
# (daemon    ) Starting 6
# (daemon    ) Event before-parameter-build.lambda.Invoke: calling handler <function generate_idempotent_uuid at 0x7f9ac0358af0>
# (daemon    ) Starting 8
# (daemon    ) Event before-parameter-build.lambda.Invoke: calling handler <function generate_idempotent_uuid at 0x7f9ac0358af0>
# (daemon    ) Starting 9
# (daemon    ) Starting 10
# (daemon    ) Event before-parameter-build.lambda.Invoke: calling handler <function generate_idempotent_uuid at 0x7f9ac0358af0>
# ...
